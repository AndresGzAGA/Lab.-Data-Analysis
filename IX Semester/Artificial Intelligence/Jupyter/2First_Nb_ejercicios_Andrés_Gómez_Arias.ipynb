# %% [markdown]
# <font color='red'>
#     <font size=4>
#
# **1. Exercise**

# %% [markdown]
# <font size=4>
#
# I. Add a cell below this. There are two ways to do it:

# %% [markdown]
# <font size=4>
#
# 1. Click on the **+** button and automatically it added a cell bellow the current cell selected.
#
# <img src='images/plus.PNG'>

# %% [markdown]
# <font size=4>
#
# 2. In the tool bar go to **Insert>Insert Cell Below**:
#
# <img src='images/cell_be.PNG'>

# %% [markdown]
# <font size=4>
#
# II. Convert cell to markdown type using any of the three methods seen.

# %% [markdown]
# <font size=4>
#
# III. Go to  [openAI](https://openai.com), choose an article of interest and write a small review. Put a title, with a color that is not black and larger than normal text.

# %% [markdown]
# <font size=4>
#
# IV. Add an image with caption.
#
# (add the necessary cells, above or below)

# %% [markdown]
# <font color='blue'>
#
# ## Review: "Generative Pretraining from Pixels"

# %% [markdown]
# <font size=3>
#
# This article uses a method similar to the one which completes a written text, but applied to the completion of images. Instead of completing alphanumeric characters, one uses rgb code on Pixels instead. Some results are shown below.

# %% [markdown]
# <img src='images/Samples.PNG'>

# %% [markdown]
# [Source: Image GPT](https://openai.com/blog/image-gpt/)

# %% [markdown]
# <font color='red'>
#     <font size=4>
#
# **2. Exercise**

# %% [markdown]
# <font size=4>
#
# I. Write the cost function binary crossentropy.
#
# You can check the equation in: [Undestanding binary crossentropy.](https://towardsdatascience.com/understanding-binary-cross-entropy-log-loss-a-visual-explanation-a3ac6025181a)
#
# If you do not know how to put a symbol you can check on this page: [Detexify](http://detexify.kirelabs.org/classify.html)

# %% [markdown]
# $$H_{p}(q) = -\frac{1}{N}\sum_{i=1}^N y_i\cdot log(p(y_i))+(1-y_i)\cdot log(1-p(y_i)) $$

# %% [markdown]
# <font size=4>
#
# <font color='red'>
#
# **3. Exercise**

# %% [markdown]
# <font size=4>
#
# I. Make a table to compare the frameworks Keras, Tensorflow and PyTorch.
#
# You can use the next link [The major differences between Tf, Keras and PyTorch](https://www.quora.com/What-are-the-major-differences-between-TensorFlow-Keras-and-PyTorch).

# %% [markdown]
# | Keras | Tensorflow | PyTorch|
# | --- | --- | --- |
# | Keras library is also for Python-based coding. | Tensorflow library is compatible with various coding languages such as C, C++, Java, etc. | The Pytorch library is only for the Python-based coding. |
# | This framework is for performing fast experiments with neural networks. | Tensorflow library has both low-level and high-level APIs. | The Pytorch library has only low-level APIs that would focus on the working of array expression.|
# | Keras library has a very high-level API that could run on CNTK and Theano. | Tensorflow is famous for its fast computational ability across several platforms. | Pytorch is generally famous for academic research purposes. It would also assist in deep learning applications. |
# | Keras is popular due to the syntactic simplicity and user-friendly nature. | The speed of Tensorflow is very fast and would provide high performance. | The speed and performance of Pytorch are very much similar to the Tensorflow. |
# | The speed of Keras slower while comparing with Tensorflow and Pytorch. | This framework is for teaching the machine about various computational methods. | This framework is for building a neural network and for natural language processing. |
# | It is designed to enable fast experimentation with deep neural networks. | Tensorflow, on the other hand, is not very easy to use even though it provides Keras as a framework that makes work easier. | PyTorch has a complex architecture and the readability is less when compared to Keras. |
# | Keras has a simple architecture. It is more readable and concise | TensorFlow is used for high-performance models and large datasets that require fast execution. | PyTorch is used for high-performance models and large datasets that require fast execution. |
# | Keras is usually used for small datasets as it is comparatively slower. | - | - |

# %% [markdown]
# <font color='red'>
# <font size=4>
#
# **4. Exercise**

# %% [markdown]
# <font size=4>
#
# I. Add the corresponding references in exercise 1.

# %% [markdown]
# [Source: Image GPT](https://openai.com/blog/image-gpt/)

# %% [markdown]
# <font color='red'>
#     <font size=4>
#
# **5. Exercise**

# %% [markdown]
# <font size=4>
#
# I. Define the sigmoid activation function.
#
# [sigmoid activation function](https://keras.io/activations/#sigmoid)

# %%
import numpy as np

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))
