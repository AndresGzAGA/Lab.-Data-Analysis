# %% [markdown]
# <font size=4 color='blue'>
#
# # <center> Clase 5, octubre 21 del 2020 </center>

# %% [markdown]
# <font size=4 color='blue'>
#
# # <center> Tópico de estudio: Mortalidad por diabetes </center>

# %% [markdown]
# <font size=4 color='blue'>
#
# ## Información sobre el tópico

# %% [markdown]
# <font size=4>
#
# Evolución de la diabetes despues de un año.
#
# En el presente trabajo, la diabetes la caracterizamos con los siguientes diez rasgos: edad, sexo, índice de masa corporal, presión arterial promedio y seis mediciones de suero sanguíneo (S1, S2, S3, S4, S5, S6).

# %% [markdown]
# <font size=4 color='blue'>
#
# ## Cuantificación de esta información

# %% [markdown]
# <font size=4>
#
# Se tienen información de 442 pacientes (m = 442). La respuesta de interés, Y, es una medida cuantitativa de la progresión de la enfermedad un año después del inicio del estudio. Los valores de Y varían entre 25 y 346
#
# Fuente de la información: [diabetes data](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html)
#
# Artículo original: [Least-Angle-Regression_2004](./Literatura/Least-Angle-Regression_2004.pdf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# Los datos se encuentran el el archivo diabetes.csv

df = pd.read_csv('diabetes.csv', sep ='\t')

# se crea el dataframe df, el cual contiene los 10 rasgos relevantes de los pacientes
# diabeticos, así como el progreso (y) de la enfermedad un año después de comenzado el estudio.

# %%
# Se despliegan las primeras 5 muestras (rasgos, objetivo)

df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
# el método describe() genera una tabla con informacion estadistica de cada uno de los rasgos y del objetivo.

df.describe()
# Out:
#               AGE         SEX         BMI          BP          S1          S2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                S3          S4          S5          S6           Y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# min     22.000000    2.000000    3.258100   58.000000   25.000000
# 25%     40.250000    3.000000    4.276700   83.250000   87.000000
# 50%     48.000000    4.000000    4.620050   91.000000  140.500000
# 75%     57.750000    5.000000    4.997200   98.000000  211.500000
# max     99.000000    9.090000    6.107000  124.000000  346.000000

# %% [markdown]
# ## Se crean los histogramas para cada uno de los rasgos que caracteriza a los pacientes con diabetes:

# %%
plt.figure(figsize=(20,8)) 

ax1 = plt.subplot(2,4,1)
ax2 = plt.subplot(2,4,2)
ax3 = plt.subplot(2,4,3)
ax4 = plt.subplot(2,4,4)

ax1.hist(df.AGE, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('Age (years)', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df.SEX, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('Sex', size=15)

ax3.hist(df.BMI, bins=30, color='red',edgecolor='purple', alpha=0.5)
ax3.set_xlabel('Body_mass_index', size=15)

ax4.hist(df.BP, bins=30, color='blue',edgecolor='purple', alpha=0.5)
ax4.set_xlabel('Average_blood_pressure', size=15);

# %%
plt.figure(figsize=(20,8)) 

ax1 = plt.subplot(2,4,1)
ax2 = plt.subplot(2,4,2)
ax3 = plt.subplot(2,4,3)
ax4 = plt.subplot(2,4,4)

ax1.hist(df.S1, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('S1', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df.S2, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('S2', size=15)

ax3.hist(df.S3, bins=30, color='red',edgecolor='purple', alpha=0.5)
ax3.set_xlabel('S3', size=15)

ax4.hist(df.S4, bins=30, color='blue',edgecolor='purple', alpha=0.5)
ax4.set_xlabel('S4', size=15);

# %%
plt.figure(figsize=(15,8)) 

ax1 = plt.subplot(2,3,1)
ax2 = plt.subplot(2,3,2)
ax3 = plt.subplot(2,3,3)

ax1.hist(df.S5, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('S5', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df.S6, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('S6', size=15)

ax3.hist(df.Y, bins=30, color='purple',edgecolor='black', alpha=0.5)
ax3.set_xlabel('Y', size=15)
# Out:
# Text(0.5, 0, 'Y')

# %% [markdown]
# <font size=4>
#
# Para quitar cualquier posible correlación entre las muestras (los renglones del DataFrame), estos se reordenan al azar.

# %%
df = df.sample(frac=1)

# %% [markdown]
# <font size=4>
#
# Se dividen la muestras originales en 2 conjuntos: 90 % para el entrenamiento y 10 % para hacer inferencias predicciones) con lo aprendido.

# %%
test_ratio = 0.1

train_ratio = int((1.0-test_ratio)*len(df.values[:,:]))

df_train = df.iloc[0:train_ratio,:]
df_test  = df.iloc[train_ratio:,:]

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (397, 11)
# (45, 11)

# %% [markdown]
# <font size=4>
#
# Para trabajar con los modelos se requiere que todas las variables tengan el mismo orden de magnitud. Por ello, se normalizan sus valores en las muestras que se van a emplear en el entrenamiento, tanto los rasgos (X) y las objetivo o referencia (Y):
#
# $$x_{norm} = \dfrac{x-\bar{x}}{\sigma}$$

# %%
df_train_norm = (df_train - df_train.mean()) / df_train.std()

# %%
df_test_norm = (df_test - df_train.mean()) / df_train.std()

# %% [markdown]
# <font size=4>
#
# Histogramas de las variables que se emplearán en el entrenamiento:

# %%
plt.figure(figsize=(20,8)) 

ax1 = plt.subplot(2,4,1)
ax2 = plt.subplot(2,4,2)
ax3 = plt.subplot(2,4,3)
ax4 = plt.subplot(2,4,4)

ax1.hist(df_train_norm.AGE, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('x1(Age)', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df_train_norm.SEX, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('x2(Sex)', size=15)

ax3.hist(df_train_norm.BMI, bins=30, color='red',edgecolor='purple', alpha=0.5)
ax3.set_xlabel('x3(Body_mass_index)', size=15)

ax4.hist(df_train_norm.BP, bins=30, color='blue',edgecolor='purple', alpha=0.5)
ax4.set_xlabel('x4(Average_blood_pressure)', size=15);

# %%
plt.figure(figsize=(20,8)) 

ax1 = plt.subplot(2,4,1)
ax2 = plt.subplot(2,4,2)
ax3 = plt.subplot(2,4,3)
ax4 = plt.subplot(2,4,4)

ax1.hist(df_train_norm.S1, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('x5(S1)', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df_train_norm.S2, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('x6(S2)', size=15)

ax3.hist(df_train_norm.S3, bins=30, color='red',edgecolor='purple', alpha=0.5)
ax3.set_xlabel('x7(S3)', size=15)

ax4.hist(df_train_norm.S4, bins=30, color='blue',edgecolor='purple', alpha=0.5)
ax4.set_xlabel('x8(S4)', size=15);

# %%
plt.figure(figsize=(20,8)) 

ax1 = plt.subplot(2,3,1)
ax2 = plt.subplot(2,3,2)
ax3 = plt.subplot(2,3,3)

ax1.hist(df_train_norm.S5, bins=30, color='green',edgecolor='purple', alpha=0.5)
ax1.set_xlabel('x9(S5)', size=15)
ax1.set_ylabel('Frequency', size=15)

ax2.hist(df_train_norm.S6, bins=30, color='orange',edgecolor='purple', alpha=0.5)
ax2.set_xlabel('x10(S6)', size=15)

ax3.hist(df_train_norm.Y, bins=30, color='purple',edgecolor='black', alpha=0.5)
ax3.set_xlabel('Y', size=15)
# Out:
# Text(0.5, 0, 'Y')

# %% [markdown]
# <font size=4>
# Los valores de las variables X e Y se extraen de las columnas del DataFrame.

# %%
train_x = df_train_norm.values[:,:-1]
train_y = df_train_norm.values[:,-1:]

# %%
test_x = df_test_norm.values[:,:-1]
test_y = df_test_norm.values[:,-1:]

# %%
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (397, 10)
# (397, 1)
# (45, 10)
# (45, 1)

# %% [markdown]
# <font size=5 color='blue'>
#
# # <center> Artificial Neural Networks </center>

# %% [markdown]
# <font size=4 color='blue'>
#
# # <center> Implemented using the framework Keras </center>
#
#
# <font size=4 color='mediumvioletred'>
#
# [Keras](https://keras.io/)

# %% [raw]
# $ conda install -c conda-forge keras

# %% [raw]
# $ conda install -c conda-forge tensorflow

# %%
from keras.models import Sequential
from keras.layers import Input, Dense, Flatten
from keras.layers import Activation
from keras.optimizers import SGD
from keras.models import Model
from keras.utils import plot_model
from keras import initializers
from keras import optimizers
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <font size=5 color='blue'>
#
# Generating a full-connected feedforward (FFF) artificial neural network.

# %%
import networkx as nx

class Network(object):
    
    def  __init__ (self,sizes):
        self.num_layers = len(sizes)
        print("It has", self.num_layers, "layers,")
        self.sizes = sizes
        print("with the following number of nodes per layer",self.sizes)
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x)
                        for x, y in zip(sizes[:-1], sizes[1:])]
        
    def feedforward(self, x_of_sample):
        """Return the output of the network F(x_of_sample) """        
        for b, w in zip(self.biases, self.weights):
            x_of_sample = sigmoid(np.dot(w, x_of_sample)+b)
        return x_of_sample
    
    def graph(self,sizes):
        a=[]
        ps={}
        Q = nx.Graph()
        for i in range(len(sizes)):
            Qi=nx.Graph()    
            n=sizes[i]
            nodos=np.arange(n)
            Qi.add_nodes_from(nodos)
            l_i=Qi.nodes
            Q = nx.union(Q, Qi, rename = (None, 'Q%i-'%i))
            if len(l_i)==1:
                ps['Q%i-0'%i]=[i/(len(sizes)), 1/2]
            else:
                for j in range(len(l_i)+1):
                    ps['Q%i-%i'%(i,j)]=[i/(len(sizes)),(1/(len(l_i)*len(l_i)))+(j/(len(l_i)))]
            a.insert(i,Qi)
        for i in range(len(a)-1):
            for j in range(len(a[i])):
                for k in range(len(a[i+1])):
                    Q.add_edge('Q%i-%i' %(i,j),'Q%i-%i' %(i+1,k))
        nx.draw(Q, pos = ps)

# %%
n_x = train_x.shape[1] 
n_h = 4
n_y = train_y.shape[1]
    
layers = [n_x, n_h, n_y]
net = Network(layers)
net.graph(layers)
# Out:
# It has 3 layers,
# with the following number of nodes per layer [10, 4, 1]

# %% [markdown]
# <font size=5 color='blue'>
#
# Architecture definition.
#
# It includes weights and biases initialization, as well as the activation functions.

# %%
model = Sequential()

input_nodes = n_x     #input layer has n_x nodes
hlayer1_nodes = n_h   #first hidden layer has n_h nodes
output_nodes = n_y    #output layer has n_y node


#For the first hidden layer, it is necessary to indicate its input layer, which corresponds to 
#the input layer of the network

model.add(Dense(hlayer1_nodes,  kernel_initializer='uniform', bias_initializer='zeros', input_dim=input_nodes, activation='tanh'))

#For any other hidden layer its input layer is not indicated. Its input layer is the hidden layer before it

#The following layer is the last layer of the network. It corresponds to the output layer of the network
model.add(Dense(output_nodes, kernel_initializer='uniform', bias_initializer='zeros', activation='linear'))

# %% [markdown]
# <font size=5 color='blue'>
# Graph and summary of the architecture

# %%
plot_model(model, to_file='model.png', show_shapes=True, rankdir='TB', 
       show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 44
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 49
# Trainable params: 49
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font size=5  color='blue'>
#
# Compiling the model. It includes the definition of the optimizer

# %%
# We define the optimizing function and their hyperparameters: learining rate(lr) in the present case

sgd = optimizers.SGD(lr=0.01)

# For this optimizer there are more hyperparameters availble. See the respective reference
# for example, 
# sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='mean_squared_error', optimizer=sgd)

# %% [markdown]
# <font size=5 color='blue'>
#
# Training the learning system

# %%
#10 % of the data for training will be used to validate the training
validation_portion = 0.1
epochs = 100

history = model.fit(train_x, train_y, epochs=epochs, validation_split = validation_portion)

# the object "history" contains information generated during the training
# Out:
# Train on 357 samples, validate on 40 samples
# Epoch 1/100
# 357/357 [==============================] - 2s 6ms/step - loss: 1.0147 - val_loss: 0.8555
# Epoch 2/100
# 357/357 [==============================] - 0s 132us/step - loss: 1.0120 - val_loss: 0.8524
# Epoch 3/100
# 357/357 [==============================] - 0s 84us/step - loss: 1.0081 - val_loss: 0.8475
# Epoch 4/100
# 357/357 [==============================] - 0s 308us/step - loss: 1.0029 - val_loss: 0.8412
# Epoch 5/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.9951 - val_loss: 0.8295
# Epoch 6/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.9799 - val_loss: 0.8128
# Epoch 7/100
# 357/357 [==============================] - 0s 286us/step - loss: 0.9583 - val_loss: 0.7877
# Epoch 8/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.9257 - val_loss: 0.7535
# Epoch 9/100
# 357/357 [==============================] - 0s 258us/step - loss: 0.8832 - val_loss: 0.7173
# Epoch 10/100
# 357/357 [==============================] - 0s 261us/step - loss: 0.8380 - val_loss: 0.6682
# Epoch 11/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.7771 - val_loss: 0.6202
# Epoch 12/100
# 357/357 [==============================] - 0s 275us/step - loss: 0.7177 - val_loss: 0.5834
# Epoch 13/100
# 357/357 [==============================] - 0s 266us/step - loss: 0.6713 - val_loss: 0.5542
# Epoch 14/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.6310 - val_loss: 0.5343
# Epoch 15/100
# 357/357 [==============================] - 0s 261us/step - loss: 0.6023 - val_loss: 0.5196
# Epoch 16/100
# 357/357 [==============================] - 0s 283us/step - loss: 0.5778 - val_loss: 0.5058
# Epoch 17/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.5600 - val_loss: 0.5012
# Epoch 18/100
# 357/357 [==============================] - 0s 261us/step - loss: 0.5474 - val_loss: 0.4935
# Epoch 19/100
# 357/357 [==============================] - 0s 308us/step - loss: 0.5376 - val_loss: 0.4873
# Epoch 20/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.5282 - val_loss: 0.4842
# Epoch 21/100
# 357/357 [==============================] - 0s 255us/step - loss: 0.5219 - val_loss: 0.4818
# Epoch 22/100
# 357/357 [==============================] - 0s 266us/step - loss: 0.5172 - val_loss: 0.4777
# Epoch 23/100
# 357/357 [==============================] - 0s 81us/step - loss: 0.5116 - val_loss: 0.4745
# Epoch 24/100
# 357/357 [==============================] - 0s 258us/step - loss: 0.5073 - val_loss: 0.4729
# Epoch 25/100
# 357/357 [==============================] - 0s 275us/step - loss: 0.5022 - val_loss: 0.4618
# Epoch 26/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4989 - val_loss: 0.4620
# Epoch 27/100
# 357/357 [==============================] - 0s 233us/step - loss: 0.4965 - val_loss: 0.4593
# Epoch 28/100
# 357/357 [==============================] - 0s 263us/step - loss: 0.4938 - val_loss: 0.4586
# Epoch 29/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4922 - val_loss: 0.4577
# Epoch 30/100
# 357/357 [==============================] - 0s 277us/step - loss: 0.4913 - val_loss: 0.4571
# Epoch 31/100
# 357/357 [==============================] - 0s 283us/step - loss: 0.4899 - val_loss: 0.4547
# Epoch 32/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4894 - val_loss: 0.4567
# Epoch 33/100
# 357/357 [==============================] - 0s 261us/step - loss: 0.4880 - val_loss: 0.4614
# Epoch 34/100
# 357/357 [==============================] - 0s 230us/step - loss: 0.4879 - val_loss: 0.4606
# Epoch 35/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.4876 - val_loss: 0.4635
# Epoch 36/100
# 357/357 [==============================] - 0s 269us/step - loss: 0.4875 - val_loss: 0.4629
# Epoch 37/100
# 357/357 [==============================] - 0s 213us/step - loss: 0.4874 - val_loss: 0.4633
# Epoch 38/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.4867 - val_loss: 0.4624
# Epoch 39/100
# 357/357 [==============================] - 0s 263us/step - loss: 0.4862 - val_loss: 0.4626
# Epoch 40/100
# 357/357 [==============================] - 0s 233us/step - loss: 0.4860 - val_loss: 0.4621
# Epoch 41/100
# 357/357 [==============================] - 0s 90us/step - loss: 0.4870 - val_loss: 0.4582
# Epoch 42/100
# 357/357 [==============================] - 0s 241us/step - loss: 0.4865 - val_loss: 0.4566
# Epoch 43/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.4863 - val_loss: 0.4690
# Epoch 44/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4865 - val_loss: 0.4689
# Epoch 45/100
# 357/357 [==============================] - 0s 275us/step - loss: 0.4857 - val_loss: 0.4685
# Epoch 46/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4854 - val_loss: 0.4677
# Epoch 47/100
# 357/357 [==============================] - 0s 255us/step - loss: 0.4861 - val_loss: 0.4684
# Epoch 48/100
# 357/357 [==============================] - 0s 261us/step - loss: 0.4858 - val_loss: 0.4641
# Epoch 49/100
# 357/357 [==============================] - 0s 81us/step - loss: 0.4855 - val_loss: 0.4660
# Epoch 50/100
# 357/357 [==============================] - 0s 213us/step - loss: 0.4850 - val_loss: 0.4623
# Epoch 51/100
# 357/357 [==============================] - 0s 266us/step - loss: 0.4856 - val_loss: 0.4685
# Epoch 52/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4853 - val_loss: 0.4712
# Epoch 53/100
# 357/357 [==============================] - 0s 255us/step - loss: 0.4852 - val_loss: 0.4691
# Epoch 54/100
# 357/357 [==============================] - 0s 280us/step - loss: 0.4851 - val_loss: 0.4662
# Epoch 55/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.4844 - val_loss: 0.4632
# Epoch 56/100
# 357/357 [==============================] - 0s 227us/step - loss: 0.4841 - val_loss: 0.4624
# Epoch 57/100
# 357/357 [==============================] - 0s 252us/step - loss: 0.4839 - val_loss: 0.4594
# Epoch 58/100
# 357/357 [==============================] - 0s 98us/step - loss: 0.4846 - val_loss: 0.4572
# Epoch 59/100
# 357/357 [==============================] - 0s 199us/step - loss: 0.4842 - val_loss: 0.4575
# Epoch 60/100
# 357/357 [==============================] - 0s 269us/step - loss: 0.4842 - val_loss: 0.4558
# Epoch 61/100
# 357/357 [==============================] - 0s 90us/step - loss: 0.4841 - val_loss: 0.4574
# Epoch 62/100
# 357/357 [==============================] - 0s 272us/step - loss: 0.4839 - val_loss: 0.4619
# Epoch 63/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4846 - val_loss: 0.4567
# Epoch 64/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.4837 - val_loss: 0.4581
# Epoch 65/100
# 357/357 [==============================] - 0s 252us/step - loss: 0.4836 - val_loss: 0.4552
# Epoch 66/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4841 - val_loss: 0.4617
# Epoch 67/100
# 357/357 [==============================] - 0s 258us/step - loss: 0.4832 - val_loss: 0.4613
# Epoch 68/100
# 357/357 [==============================] - 0s 314us/step - loss: 0.4826 - val_loss: 0.4574
# Epoch 69/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4831 - val_loss: 0.4584
# Epoch 70/100
# 357/357 [==============================] - 0s 261us/step - loss: 0.4829 - val_loss: 0.4642
# Epoch 71/100
# 357/357 [==============================] - 0s 266us/step - loss: 0.4833 - val_loss: 0.4696
# Epoch 72/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4833 - val_loss: 0.4678
# Epoch 73/100
# 357/357 [==============================] - 0s 263us/step - loss: 0.4834 - val_loss: 0.4660
# Epoch 74/100
# 357/357 [==============================] - 0s 280us/step - loss: 0.4835 - val_loss: 0.4632
# Epoch 75/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4826 - val_loss: 0.4599
# Epoch 76/100
# 357/357 [==============================] - 0s 272us/step - loss: 0.4827 - val_loss: 0.4612
# Epoch 77/100
# 357/357 [==============================] - 0s 263us/step - loss: 0.4822 - val_loss: 0.4613
# Epoch 78/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4823 - val_loss: 0.4565
# Epoch 79/100
# 357/357 [==============================] - 0s 328us/step - loss: 0.4824 - val_loss: 0.4556
# Epoch 80/100
# 357/357 [==============================] - 0s 238us/step - loss: 0.4827 - val_loss: 0.4559
# Epoch 81/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.4826 - val_loss: 0.4560
# Epoch 82/100
# 357/357 [==============================] - 0s 255us/step - loss: 0.4825 - val_loss: 0.4597
# Epoch 83/100
# 357/357 [==============================] - 0s 244us/step - loss: 0.4817 - val_loss: 0.4592
# Epoch 84/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4814 - val_loss: 0.4613
# Epoch 85/100
# 357/357 [==============================] - 0s 252us/step - loss: 0.4808 - val_loss: 0.4619
# Epoch 86/100
# 357/357 [==============================] - 0s 210us/step - loss: 0.4818 - val_loss: 0.4623
# Epoch 87/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.4806 - val_loss: 0.4626
# Epoch 88/100
# 357/357 [==============================] - 0s 252us/step - loss: 0.4806 - val_loss: 0.4623
# Epoch 89/100
# 357/357 [==============================] - 0s 218us/step - loss: 0.4821 - val_loss: 0.4613
# Epoch 90/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.4810 - val_loss: 0.4614
# Epoch 91/100
# 357/357 [==============================] - 0s 221us/step - loss: 0.4813 - val_loss: 0.4593
# Epoch 92/100
# 357/357 [==============================] - 0s 224us/step - loss: 0.4799 - val_loss: 0.4592
# Epoch 93/100
# 357/357 [==============================] - 0s 90us/step - loss: 0.4805 - val_loss: 0.4608
# Epoch 94/100
# 357/357 [==============================] - 0s 221us/step - loss: 0.4804 - val_loss: 0.4606
# Epoch 95/100
# 357/357 [==============================] - 0s 84us/step - loss: 0.4798 - val_loss: 0.4656
# Epoch 96/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.4806 - val_loss: 0.4654
# Epoch 97/100
# 357/357 [==============================] - 0s 261us/step - loss: 0.4793 - val_loss: 0.4692
# Epoch 98/100
# 357/357 [==============================] - 0s 87us/step - loss: 0.4796 - val_loss: 0.4735
# Epoch 99/100
# 357/357 [==============================] - 0s 241us/step - loss: 0.4793 - val_loss: 0.4697
# Epoch 100/100
# 357/357 [==============================] - 0s 120us/step - loss: 0.4800 - val_loss: 0.4710

# %% [markdown]
# <font size=5 color='blue'>
#
# Plots of the costs functions versus epoch

# %%
plt.figure(figsize=(10, 7))

plt.plot(history.history['loss'], color='red')
plt.plot(history.history['val_loss'], color='green')
plt.title('Cost function')
plt.ylabel('cost')
plt.xlabel('epoch')
plt.legend(['cost_train', 'cost_validation'])
plt.show()

# %%
#history_model.history

# %% [markdown]
# <font size = 5 color = 'blue'>
#
# Evaluation of the learning.
#
# This is done using the test data.

# %%
preds = model.evaluate(x=test_x, y=test_y)

print ("Loss = " + str(preds))
# Out:
# 45/45 [==============================] - 0s 889us/step
# Loss = 0.5795059243837992

# %%
prediction = model.predict(test_x)

# %%
prediction[0]
# Out:
# array([-1.0431355], dtype=float32)
